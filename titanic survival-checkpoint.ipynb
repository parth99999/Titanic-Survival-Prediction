# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Train.csv")

# %%
df.head()
# Out:
#    pclass  survived                                            name     sex  \
# 0     3.0       0.0                         O'Donoghue, Ms. Bridget  female
# 1     2.0       0.0  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male
# 2     2.0       1.0                       Smith, Miss. Marion Elsie  female
# 3     3.0       1.0  Goldsmith, Mrs. Frank John (Emily Alice Brown)  female
# 4     3.0       1.0                              McCoy, Miss. Agnes  female
#
#     age  sibsp  parch  ticket    fare cabin embarked boat  body  \
# 0   NaN    0.0    0.0  364856   7.750   NaN        Q  NaN   NaN
# 1  39.0    0.0    0.0  250655  26.000   NaN        S  NaN   NaN
# 2  40.0    0.0    0.0   31418  13.000   NaN        S    9   NaN
# 3  31.0    1.0    1.0  363291  20.525   NaN        S  C D   NaN
# 4   NaN    2.0    0.0  367226  23.250   NaN        Q   16   NaN
#
#                            home.dest
# 0                                NaN
# 1                                NaN
# ...

# %%
column_drop=["name","boat","body","home.dest","cabin","embarked","ticket"]

# %%
data_clean=df.drop(column_drop,axis=1)

# %%
data_clean.head()
# Out:
#    pclass  survived     sex   age  sibsp  parch    fare
# 0     3.0       0.0  female   NaN    0.0    0.0   7.750
# 1     2.0       0.0    male  39.0    0.0    0.0  26.000
# 2     2.0       1.0  female  40.0    0.0    0.0  13.000
# 3     3.0       1.0  female  31.0    1.0    1.0  20.525
# 4     3.0       1.0  female   NaN    2.0    0.0  23.250

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

data_clean["sex"] = le.fit_transform(data_clean["sex"])

# %%
data_clean
# Out:
#       pclass  survived  sex   age  sibsp  parch      fare
# 0        3.0       0.0    0   NaN    0.0    0.0    7.7500
# 1        2.0       0.0    1  39.0    0.0    0.0   26.0000
# 2        2.0       1.0    0  40.0    0.0    0.0   13.0000
# 3        3.0       1.0    0  31.0    1.0    1.0   20.5250
# 4        3.0       1.0    0   NaN    2.0    0.0   23.2500
# 5        2.0       0.0    1  16.0    0.0    0.0   26.0000
# 6        2.0       0.0    1  43.0    0.0    1.0   21.0000
# 7        1.0       1.0    0  49.0    0.0    0.0   25.9292
# 8        1.0       0.0    1  48.0    0.0    0.0   50.4958
# 9        2.0       0.0    1   NaN    0.0    0.0   12.8750
# 10       2.0       0.0    1  21.0    2.0    0.0   73.5000
# 11       3.0       1.0    0   NaN    0.0    0.0    7.8292
# 12       2.0       1.0    0  48.0    0.0    2.0   36.7500
# 13       2.0       1.0    1   8.0    1.0    1.0   36.7500
# 14       3.0       0.0    1  22.0    0.0    0.0    7.8958
# ...

# %%
data_clean = data_clean.fillna(data_clean["age"].mean())

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer()
si.fit_transform(data_clean)
# Out:
# array([[  3.    ,   0.    ,   0.    , ...,   0.    ,   0.    ,   7.75  ],
#        [  2.    ,   0.    ,   1.    , ...,   0.    ,   0.    ,  26.    ],
#        [  2.    ,   1.    ,   0.    , ...,   0.    ,   0.    ,  13.    ],
#        ...,
#        [  1.    ,   1.    ,   0.    , ...,   1.    ,   0.    , 113.275 ],
#        [  3.    ,   1.    ,   1.    , ...,   1.    ,   0.    ,  11.2417],
#        [  3.    ,   0.    ,   1.    , ...,   0.    ,   0.    ,   8.05  ]])

# %%
data_clean
# Out:
#       pclass  survived  sex        age  sibsp  parch      fare
# 0        3.0       0.0    0  29.838978    0.0    0.0    7.7500
# 1        2.0       0.0    1  39.000000    0.0    0.0   26.0000
# 2        2.0       1.0    0  40.000000    0.0    0.0   13.0000
# 3        3.0       1.0    0  31.000000    1.0    1.0   20.5250
# 4        3.0       1.0    0  29.838978    2.0    0.0   23.2500
# 5        2.0       0.0    1  16.000000    0.0    0.0   26.0000
# 6        2.0       0.0    1  43.000000    0.0    1.0   21.0000
# 7        1.0       1.0    0  49.000000    0.0    0.0   25.9292
# 8        1.0       0.0    1  48.000000    0.0    0.0   50.4958
# 9        2.0       0.0    1  29.838978    0.0    0.0   12.8750
# 10       2.0       0.0    1  21.000000    2.0    0.0   73.5000
# 11       3.0       1.0    0  29.838978    0.0    0.0    7.8292
# 12       2.0       1.0    0  48.000000    0.0    2.0   36.7500
# 13       2.0       1.0    1   8.000000    1.0    1.0   36.7500
# ...

# %%
input_cols = ['pclass',"sex","age","sibsp","parch","fare"]
output_cols = ["survived"]

X = data_clean[input_cols]
Y = data_clean[output_cols]

print(X.shape,Y.shape)
print(type(X))
# Out:
# (1009, 6) (1009, 1)
# <class 'pandas.core.frame.DataFrame'>

# %%
def entropy(col):
    
    counts = np.unique(col,return_counts=True)
    N = float(col.shape[0])
    
    ent = 0.0
    
    for ix in counts[1]:
        p  = ix/N
        ent += (-1.0*p*np.log2(p))
    
    return ent

# %%
def divide_data(x_data,fkey,fval):
   
    x_right = pd.DataFrame([],columns=x_data.columns)
    x_left = pd.DataFrame([],columns=x_data.columns)
    
    for ix in range(x_data.shape[0]):
        val = x_data[fkey].loc[ix]
        
        if val > fval:
            x_right = x_right.append(x_data.loc[ix])
        else:
            x_left = x_left.append(x_data.loc[ix])
            
    return x_left,x_right

# %%
def information_gain(x_data,fkey,fval):
    
    left,right = divide_data(x_data,fkey,fval)
    
   
    l = float(left.shape[0])/x_data.shape[0]
    r = float(right.shape[0])/x_data.shape[0]
    
   
    if left.shape[0] == 0 or right.shape[0] ==0:
        return -1000000
    
    i_gain = entropy(x_data.survived) - (l*entropy(left.survived)+r*entropy(right.survived))
    return i_gain

# %%
for fx in X.columns:
    print(fx)
    print(information_gain(data_clean,fx,data_clean[fx].mean()))
# Out:
# pclass
# 0.055456910002982474
# sex
# 0.19274737190850932
# age
# 0.0010525742338489685
# sibsp
# 0.006492394392888956
# parch
# 0.01975608012294816
# fare
# 0.04242793401428169

# %%
class DecisionTree:
    
    #Constructor
    def __init__(self,depth=0,max_depth=5):
        self.left = None
        self.right = None
        self.fkey = None
        self.fval = None
        self.max_depth = max_depth
        self.depth = depth
        self.target = None
        
    def train(self,X_train):
        
        features = ['pclass','sex','age','sibsp', 'parch', 'fare']
        info_gains = []
        
        for ix in features:
            i_gain = information_gain(X_train,ix,X_train[ix].mean())
            info_gains.append(i_gain)
            
        self.fkey = features[np.argmax(info_gains)]
        self.fval = X_train[self.fkey].mean()
        print("Making Tree Features is",self.fkey)
        
        #Split Data
        data_left,data_right = divide_data(X_train,self.fkey,self.fval)
        data_left = data_left.reset_index(drop=True)
        data_right = data_right.reset_index(drop=True)
         
        #Truly a left node
        if data_left.shape[0]  == 0 or data_right.shape[0] ==0:
            if X_train.survived.mean() >= 0.5:
                self.target = "Survive"
            else:
                self.target = "Dead"
            return
        #Stop earyly when depth >=max depth
        if(self.depth>=self.max_depth):
            if X_train.survived.mean() >= 0.5:
                self.target = "Survive"
            else:
                self.target = "Dead"
            return
        
        #Recursive Case
        self.left = DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.left.train(data_left)
        
        self.right = DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.right.train(data_right)
        
        #You can set the target at every node
        if X_train.survived.mean() >= 0.5:
            self.target = "Survive"
        else:
            self.target = "Dead"
        return
    
    def predict(self,test):
        if test[self.fkey]>self.fval:
            #go to right
            if self.right is None:
                return self.target
            return self.right.predict(test)
        else:
            if self.left is None:
                return self.target
            return self.left.predict(test)

split = int(0.7*data_clean.shape[0])
train_data = data_clean[:split]
test_data = data_clean[split:]
test_data = test_data.reset_index(drop=True)

# %%
dt = DecisionTree()

# %%
split = int(0.6*data_clean.shape[0])
train_data = data_clean[:split]
test_data = data_clean[split:]
test_data = test_data.reset_index(drop=True)

# %%
dt.train(train_data)
# Out:
# Making Tree Features is sex
# Making Tree Features is pclass
# Making Tree Features is pclass
# Making Tree Features is parch
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is parch
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is parch
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is sibsp
# Making Tree Features is parch
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is fare
# Making Tree Features is parch
# Making Tree Features is age
# Making Tree Features is age
# Making Tree Features is sibsp
# Making Tree Features is parch
# Making Tree Features is fare
# Making Tree Features is parch
# Making Tree Features is sibsp
# Making Tree Features is sibsp
# Making Tree Features is age
# ...

# %%
y_pred = []
for ix in range(test_data.shape[0]):
    y_pred.append(dt.predict(test_data.loc[ix]))

# %%
y_pred
# Out:
# ['Survive',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Survive',
#  'Survive',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Survive',
#  'Survive',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Survive',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Dead',
#  'Survive',
#  'Dead',
#  'Dead',
# ...

# %%
df2=pd.read_csv("Test.csv")

# %%
column_drop=["name","boat","body","home.dest","cabin","embarked","ticket"]

# %%
data_cleanxt=df2.drop(column_drop,axis=1)

# %%
data_cleanxt
# Out:
#      pclass     sex   age  sibsp  parch      fare
# 0       1.0    male  36.0    0.0    0.0   26.3875
# 1       3.0  female   NaN    8.0    2.0   69.5500
# 2       1.0    male   NaN    0.0    0.0   50.0000
# 3       2.0    male  34.0    0.0    0.0   13.0000
# 4       2.0    male  28.0    0.0    0.0   13.0000
# 5       2.0  female  31.0    1.0    1.0   26.2500
# 6       1.0    male  40.0    0.0    0.0   27.7208
# 7       3.0    male   NaN    0.0    0.0    7.2292
# 8       3.0    male  22.0    0.0    0.0    8.0500
# 9       1.0    male  30.0    0.0    0.0   45.5000
# 10      3.0    male   NaN    0.0    0.0    7.2250
# 11      3.0    male   NaN    1.0    0.0   24.1500
# 12      1.0    male  31.0    0.0    0.0   28.5375
# 13      3.0    male   NaN    0.0    0.0    8.0500
# 14      2.0  female  19.0    1.0    0.0   26.0000
# 15      3.0    male   NaN    0.0    0.0    7.5500
# 16      3.0    male   NaN    1.0    0.0    7.7500
# 17      2.0  female  34.0    0.0    0.0   10.5000
# ...

# %%
data_cleanxt["sex"] = le.fit_transform(data_cleanxt["sex"])

# %%
data_cleanxt = data_cleanxt.fillna(data_clean["age"].mean())

# %%
si.fit_transform(data_cleanxt)
# Out:
# array([[ 1.        ,  1.        , 36.        ,  0.        ,  0.        ,
#         26.3875    ],
#        [ 3.        ,  0.        , 29.83897783,  8.        ,  2.        ,
#         69.55      ],
#        [ 1.        ,  1.        , 29.83897783,  0.        ,  0.        ,
#         50.        ],
#        ...,
#        [ 3.        ,  1.        , 13.        ,  4.        ,  2.        ,
#         31.3875    ],
#        [ 3.        ,  1.        , 29.83897783,  2.        ,  0.        ,
#         21.6792    ],
#        [ 3.        ,  0.        , 29.83897783,  0.        ,  0.        ,
#          7.75      ]])

# %%
x_test=data_cleanxt[input_cols]

# %%
# Out:
#      pclass  sex        age  sibsp  parch      fare
# 0       1.0    1  36.000000    0.0    0.0   26.3875
# 1       3.0    0  29.838978    8.0    2.0   69.5500
# 2       1.0    1  29.838978    0.0    0.0   50.0000
# 3       2.0    1  34.000000    0.0    0.0   13.0000
# 4       2.0    1  28.000000    0.0    0.0   13.0000
# 5       2.0    0  31.000000    1.0    1.0   26.2500
# 6       1.0    1  40.000000    0.0    0.0   27.7208
# 7       3.0    1  29.838978    0.0    0.0    7.2292
# 8       3.0    1  22.000000    0.0    0.0    8.0500
# 9       1.0    1  30.000000    0.0    0.0   45.5000
# 10      3.0    1  29.838978    0.0    0.0    7.2250
# 11      3.0    1  29.838978    1.0    0.0   24.1500
# 12      1.0    1  31.000000    0.0    0.0   28.5375
# 13      3.0    1  29.838978    0.0    0.0    8.0500
# 14      2.0    0  19.000000    1.0    0.0   26.0000
# 15      3.0    1  29.838978    0.0    0.0    7.5500
# 16      3.0    1  29.838978    1.0    0.0    7.7500
# ...

# %%
y_predx = []
for ix in range(test_data.shape[0]):
    y_pred.append(dt.predict(test_data.loc[ix]))

# %%
y_pred = le.fit_transform(y_pred)

# %%
df3=pd.DataFrame(y_pred,columns=["survived"])

# %%
df3.to_csv?

# %%
df3.to_csv("predictionst.csv",index_label="Id")

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d=DecisionTreeClassifier?

# %%
d=DecisionTreeClassifier(criterion='entropy')

# %%
d.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
d.score(X,Y)
# Out:
# 0.9702675916749257

# %%
from sklearn.model_selection import train_test_split
xt,xx,yt,yy=train_test_split(X,Y,test_size=0.3)

# %%
d.fit(xt,yt)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
p=d.predict(xx)
